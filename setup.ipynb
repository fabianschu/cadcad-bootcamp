# %% [markdown]
# <span style="display:block;text-align:center;margin-right:105px"><img src="./media/logos/logo-vertical.png" width="200"/></span>

# %% [markdown]
# # Environment Setup

# %% [markdown]
# 1. Select Jupyter Python kernel
# 2. Install package dependencies
# 3. Ensure correct package versions are installed

# %% [markdown]
# ## Install dependencies

# %%
# %pip install -r requirements.txt
# Out:
# Collecting cadCAD==0.4.23
#   Using cached cadCAD-0.4.23-py3-none-any.whl (76 kB)
# Collecting jupyterlab==2.2.0
#   Using cached jupyterlab-2.2.0-py3-none-any.whl (7.8 MB)
# Collecting matplotlib==3.3.0
#   Using cached matplotlib-3.3.0.tar.gz (38.8 MB)
#   Preparing metadata (setup.py) ... done
# Collecting seaborn==0.10.1
#   Using cached seaborn-0.10.1-py3-none-any.whl (215 kB)
# Collecting jupyter==1.0.0
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting notebook==6.0.3
#   Using cached notebook-6.0.3-py3-none-any.whl (9.7 MB)
# Collecting ipykernel==5.3.2
#   Using cached ipykernel-5.3.2-py3-none-any.whl (120 kB)
# Collecting ipywidgets>=7.5
#   Using cached ipywidgets-8.0.4-py3-none-any.whl (137 kB)
# Collecting plotly==4.11.0
#   Using cached plotly-4.11.0-py2.py3-none-any.whl (13.1 MB)
# Collecting statsmodels==0.13.2
#   Using cached statsmodels-0.13.2-cp39-cp39-macosx_10_9_x86_64.whl (9.6 MB)
# Collecting pathos
#   Using cached pathos-0.3.0-py3-none-any.whl (79 kB)
# Collecting pandas
#   Using cached pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
# Collecting funcy
#   Using cached funcy-1.18-py2.py3-none-any.whl (33 kB)
# Collecting fn
#   Using cached fn-0.4.3.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2>=2.10 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyterlab==2.2.0->-r requirements.txt (line 2)) (3.1.2)
# Collecting jupyterlab-server<2.0,>=1.1.5
#   Using cached jupyterlab_server-1.2.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: tornado!=6.0.0,!=6.0.1,!=6.0.2 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyterlab==2.2.0->-r requirements.txt (line 2)) (6.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# Collecting numpy>=1.15
#   Using cached numpy-1.24.1-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.4.0-2-cp39-cp39-macosx_10_10_x86_64.whl (3.3 MB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from matplotlib==3.3.0->-r requirements.txt (line 3)) (2.8.2)
# Collecting scipy>=1.0.1
#   Using cached scipy-1.10.0-cp39-cp39-macosx_10_15_x86_64.whl (35.2 MB)
# Requirement already satisfied: nbconvert in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyter==1.0.0->-r requirements.txt (line 5)) (6.5.4)
# Collecting qtconsole
#   Using cached qtconsole-5.4.0-py3-none-any.whl (121 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: nbformat in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (5.7.0)
# Requirement already satisfied: Send2Trash in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: pyzmq>=17 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (7.4.8)
# Requirement already satisfied: ipython-genutils in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: terminado>=0.8.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from notebook==6.0.3->-r requirements.txt (line 6)) (0.14.1)
# Requirement already satisfied: appnope in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipykernel==5.3.2->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: ipython>=5.0.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipykernel==5.3.2->-r requirements.txt (line 7)) (8.8.0)
# Collecting retrying>=1.3.3
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from plotly==4.11.0->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from statsmodels==0.13.2->-r requirements.txt (line 10)) (22.0)
# Collecting patsy>=0.5.2
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Collecting jupyterlab-widgets~=3.0
#   Using cached jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
# Collecting widgetsnbextension~=4.0
#   Using cached widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: matplotlib-inline in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (2.11.2)
# Requirement already satisfied: decorator in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: stack-data in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: backcall in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (3.0.36)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jinja2>=2.10->jupyterlab==2.2.0->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyter-client>=5.3.4->notebook==6.0.3->-r requirements.txt (line 6)) (1.5.6)
# Requirement already satisfied: entrypoints in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyter-client>=5.3.4->notebook==6.0.3->-r requirements.txt (line 6)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyter-core>=4.6.1->notebook==6.0.3->-r requirements.txt (line 6)) (2.5.2)
# Collecting requests
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting json5
#   Using cached json5-0.9.11-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2.0->-r requirements.txt (line 2)) (4.16.0)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# Requirement already satisfied: ptyprocess in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from terminado>=0.8.1->notebook==6.0.3->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (0.5.13)
# Requirement already satisfied: lxml in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: tinycss2 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (4.11.1)
# Requirement already satisfied: defusedxml in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: bleach in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: fastjsonschema in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from nbformat->notebook==6.0.3->-r requirements.txt (line 6)) (2.16.2)
# Collecting multiprocess>=0.70.14
#   Using cached multiprocess-0.70.14-py39-none-any.whl (132 kB)
# Collecting pox>=0.3.2
#   Using cached pox-0.3.2-py3-none-any.whl (29 kB)
# Collecting ppft>=1.7.6.6
#   Using cached ppft-1.7.6.6-py3-none-any.whl (52 kB)
# Collecting dill>=0.3.6
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.0-py3-none-any.whl (83 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2.0->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2.0->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: wcwidth in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from bleach->nbconvert->jupyter==1.0.0->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2.0->-r requirements.txt (line 2)) (2022.12.7)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.0.1-cp39-cp39-macosx_10_9_x86_64.whl (124 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2.0->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: asttokens in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from stack-data->ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: executing in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from stack-data->ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages (from stack-data->ipython>=5.0.0->ipykernel==5.3.2->-r requirements.txt (line 7)) (0.2.2)
# Building wheels for collected packages: matplotlib, fn
#   Building wheel for matplotlib (setup.py) ... done
#   Created wheel for matplotlib: filename=matplotlib-3.3.0-cp39-cp39-macosx_10_9_x86_64.whl size=8431756 sha256=5c03d76721590487808acfdd315a02d1db71c4e8c247436ad757841b68f9d0c1
#   Stored in directory: /Users/fuschu/Library/Caches/pip/wheels/23/cd/28/dd4f8b8020614aac926e323e204844a5c1edfbbb6785f6721d
#   Building wheel for fn (setup.py) ... done
#   Created wheel for fn: filename=fn-0.4.3-py3-none-any.whl size=28221 sha256=d8aa4cf4b22e11e6ef9e9225a5f145f077ed0e3d19c6fd44462c73ef9a2f8c5d
#   Stored in directory: /Users/fuschu/Library/Caches/pip/wheels/aa/d9/18/6984b1417ac735489a1bf585d4a3510a409fe0e3372f48537c
# Successfully built matplotlib fn
# Installing collected packages: pytz, json5, funcy, fn, charset-normalizer, widgetsnbextension, urllib3, retrying, qtpy, pyparsing, ppft, pox, pillow, numpy, kiwisolver, jupyterlab-widgets, dill, cycler, scipy, requests, plotly, patsy, pandas, multiprocess, matplotlib, statsmodels, seaborn, pathos, ipykernel, cadCAD, qtconsole, notebook, jupyter-console, ipywidgets, jupyterlab-server, jupyter, jupyterlab
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.19.2
#     Uninstalling ipykernel-6.19.2:
#       Successfully uninstalled ipykernel-6.19.2
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.2
#     Uninstalling notebook-6.5.2:
#       Successfully uninstalled notebook-6.5.2
# Successfully installed cadCAD-0.4.23 charset-normalizer-3.0.1 cycler-0.11.0 dill-0.3.6 fn-0.4.3 funcy-1.18 ipykernel-5.3.2 ipywidgets-8.0.4 json5-0.9.11 jupyter-1.0.0 jupyter-console-6.4.4 jupyterlab-2.2.0 jupyterlab-server-1.2.0 jupyterlab-widgets-3.0.5 kiwisolver-1.4.4 matplotlib-3.3.0 multiprocess-0.70.14 notebook-6.0.3 numpy-1.24.1 pandas-1.5.3 pathos-0.3.0 patsy-0.5.3 pillow-9.4.0 plotly-4.11.0 pox-0.3.2 ppft-1.7.6.6 pyparsing-3.0.9 pytz-2022.7.1 qtconsole-5.4.0 qtpy-2.3.0 requests-2.28.2 retrying-1.3.4 scipy-1.10.0 seaborn-0.10.1 statsmodels-0.13.2 urllib3-1.26.14 widgetsnbextension-4.0.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Check package version

# %%
# %pip show cadCAD
# Out:
# Name: cadCAD
# Version: 0.4.23
# Summary: cadCAD: a differential games based simulation software package for research, validation, and         Computer Aided Design of economic systems
# Home-page: https://github.com/cadCAD-org/cadCAD
# Author: Joshua E. Jodesty
# Author-email: joshua@block.science
# License: LICENSE.txt
# Location: /Users/fuschu/opt/anaconda3/envs/cadcad-edu/lib/python3.9/site-packages
# Requires: fn, funcy, pandas, pathos
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import module

# %%
import cadCAD

# %% [markdown]
# ## Call module function

# %%
cadCAD.name
# Out:
# 'cadCAD'

# %% [markdown]
# ## Creating variables & displaying results

# %%
a = 2

def square(x):
    return x**2

# %%
output = square(a)
output
# Out:
# 4

# %%
a = 1
print(a)

a += 1
print(a)

a;
# Out:
# 1
# 2

# %%
print(a)
# Out:
# 2

# %% [markdown]
# ## Display visualizations

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
ts = pd.Series(np.random.randn(1000),
    index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
    
df = pd.DataFrame(np.random.randn(1000, 4),
                index=ts.index, columns=list('ABCD'))
df = df.cumsum()
plt.figure();
df.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde');

# %% [markdown]
# <br/><br/><br/>
# # Well done!
# <br/><br/><br/><br/>
